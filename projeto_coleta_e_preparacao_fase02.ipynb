# %% [markdown]
# <a href="https://colab.research.google.com/github/SabrinaDantas/projeto_coleta_e_preparacao_pucrs/blob/main/projeto_coleta_e_preparacao_fase02.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Coleta e Preparação de Dados

# %% [markdown]
# ## Bibliotecas

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# ## Leitura de DataFrames, Criando a Coluna 'Ano' para Análises e Organizando Nomes de Colunas

# %% [markdown]
# 1. Para combinar as bases de dados e facilitar análises que possam exigir uma análise anual, foi criada uma nova coluna com o ano correspondente ao DataFrame.

# %% [markdown]
# 2. Em nossos DataFrames, temos colunas com nomes extensos que dificultam a visualização dos dados. Portanto, vamos transformar as colunas nas seguintes chaves:
#
#
#   |Chave|Coluna|
#   |:------:|:-----|
#   |Q1|A sua empresa oferece beneficios referentes a saude mental como parte dos beneficios de saude?|
#   |Q2|A sua empresa ja debateu saude mental formalmente (por exemplo, via um programa de concientizacao corporativo)?|
#   |Q3|A sua empresa oferece recursos para aprender mais sobre saude mental e alternativas para buscar ajuda?|
#   |Q4|A sua privacidade eh protegida se voce optar por um tratamento de saude mental oferecido pela sua empresa?|
#   |Q5|Caso voce sinta a necessidade de solicitar uma licenca do trabalho devido a saude mental, quao facil ou dificil seria fazer essa solicitacao?|
#   |Q6|Voce se sentiria confortavel discutindo uma questao de saude mental com o seu chefe direto?|
#   |Q7|Voce se sentiria confortavel discutindo uma questao de saude mental com os seus pares?|
#   |Q8|O quao propenso voce estaria em dividir com amigos e familiares que voce possui uma doenca mental?|
#   |Q9|Se voce revelou uma doenca mental para um cliente ou contato de negocio, como isso afetou voce e/ou o relacionamento?|
#   |Q10|Se voce revelou uma doenca mental para um para par ou funcionario, como isso afetou voce e/ou o relacionamento?|
#   |Q11|Idade|
#   |Q12|Genero|
#   |Q13|Qual pais voce reside?|
#   |Q14|Qual pais voce trabalha?|
#   |Q15|Voce ja foi diagnosticado com uma doenca mental?|
#   |Q16|Voce ja procurou tratamento profissional para uma doenca mental?|
#   |Q17|Ano|

# %% [markdown]
# ### 2016

# %%
#Leitura do DataFrame
df_2016 = pd.read_csv('2016_f.csv')

# #Inserindo a coluna ano
ano_2016 = 2016
df_2016['Ano'] = ano_2016

# # #Renomeando as colunas para chaves
keys_2016 = ['Q{}'.format(i) for i in range(1,18)]
columns_dic_2016 = pd.Series(df_2016.columns, index=keys_2016)
df_2016.columns = keys_2016


df_2016.sample(5)
# Out:
#               Q1   Q2          Q3          Q4             Q5      Q6      Q7  \
# 896          Nao  Nao  Eu nao sei  Eu nao sei    Muito Facil     Sim     Sim
# 32    Eu nao sei  Nao         Nao  Eu nao sei    Muito Facil  Talvez     Nao
# 1106         Sim  Nao  Eu nao sei  Eu nao sei    Muito Facil     Sim  Talvez
# 1055  Eu nao sei  Nao         Nao         Nao  Muito dificil     Nao  Talvez
# 157   Eu nao sei  Sim         Nao  Eu nao sei    Muito Facil  Talvez     Nao
#
#                                                  Q8   Q9  Q10   Q11  \
# 896                                          Neutro  NaN  NaN  29.0
# 32                                  Um pouco aberto  NaN  NaN  31.0
# 1106                                Um pouco aberto  NaN  NaN  31.0
# 1055                               Nao muito aberto  NaN  NaN  29.0
# 157   Nao aplicavel, eu nao tenho uma doenca mental  NaN  NaN  37.0
#
#             Q12            Q13            Q14  Q15  Q16   Q17
# ...

# %% [markdown]
# ### 2017

# %%
#Leitura do DataFrame
df_2017 = pd.read_csv('2017_f.csv')

#Inserindo a coluna ano
ano_2017 = 2017
df_2017['Ano'] = ano_2017

#Renomeando as colunas para chaves
keys_2017 = ['Q{}'.format(i) for i in range(1,18)]
columns_dic_2017 = pd.Series(df_2017.columns, index=keys_2017)
df_2017.columns = keys_2017

df_2017.sample(5)
# Out:
#              Q1   Q2          Q3          Q4                     Q5   Q6  \
# 298         Nao  Nao         Nao  Eu nao sei                  Facil  Nao
# 496         Sim  Nao         Nao  Eu nao sei             Eu nao sei  Nao
# 389         Sim  Nao  Eu nao sei         Sim  Nem facil nem dificil  Nao
# 310  Eu nao sei  Sim         Sim         Sim                  Facil  Sim
# 188         Sim  Nao         Nao  Eu nao sei  Nem facil nem dificil  Nao
#
#          Q7  Q8   Q9  Q10   Q11        Q12             Q13             Q14  \
# 298     Nao   7  NaN  NaN  32.0  Masculino     Netherlands     Netherlands
# 496  Talvez   1  NaN  NaN  27.0   feminino   United States   United States
# 389  Talvez  10  NaN  NaN  52.0  Masculino   United States   United States
# 310  Talvez   7  NaN  NaN  32.0  Masculino  United Kingdom  United Kingdom
# 188     Sim   6  NaN  NaN  25.0  Masculino   United States   United States
#
#      Q15  Q16   Q17
# 298  NaN  Nao  2017
# 496  Sim  Sim  2017
# ...

# %% [markdown]
# ### 2018

# %%
#Leitura do DataFrame
df_2018 = pd.read_csv('2018_f.csv')

#Inserindo a coluna ano
ano_2018 = 2018
df_2018['Ano'] = ano_2018

#Renomeando as colunas para chaves
keys_2018 = ['Q{}'.format(i) for i in range(1,18)]
columns_dic_2018 = pd.Series(df_2018.columns, index=keys_2018)
df_2018.columns = keys_2018

df_2018.sample(5)
# Out:
#              Q1   Q2   Q3          Q4          Q5      Q6      Q7  Q8   Q9  \
# 280         Sim  Sim  Sim         Sim       Facil     Sim     Sim   8  NaN
# 325  Eu nao sei  Nao  Nao  Eu nao sei  Eu nao sei  Talvez  Talvez   6  NaN
# 56   Eu nao sei  Nao  Nao  Eu nao sei     Dificil     Sim     Nao   6  NaN
# 186         NaN  NaN  NaN         NaN         NaN     NaN     NaN   8  NaN
# 200         Nao  Nao  Nao  Eu nao sei     Dificil     Nao  Talvez   8  NaN
#
#                Q10   Q11        Q12            Q13            Q14  Q15  Q16  \
# 280            NaN  36.0     outros  United States  United States  Sim  Sim
# 325            NaN  42.0  Masculino  United States  United States  NaN  Nao
# 56             NaN  28.0  Masculino  United States  United States  NaN  Nao
# 186  Nao aplicavel  32.0  Masculino  United States  United States  NaN  Nao
# 200            NaN  31.0   feminino        Germany        Germany  Sim  Sim
#
#       Q17
# 280  2018
# 325  2018
# 56   2018
# 186  2018
# ...

# %% [markdown]
# ### 2019

# %%
#Leitura do DataFrame
df_2019 = pd.read_csv('2019_f.csv')

#Inserindo a coluna ano
ano_2019 = 2019
df_2019['Ano'] = ano_2019

#Renomeando as colunas para chaves
keys_2019 = ['Q{}'.format(i) for i in range(1,18)]
columns_dic_2019 = pd.Series(df_2019.columns, index=keys_2019)
df_2019.columns = keys_2019

df_2019.sample(5)
# Out:
#       Q1   Q2          Q3          Q4                     Q5      Q6      Q7  \
# 6    Sim  Nao  Eu nao sei         Sim                  Facil  Talvez  Talvez
# 140  NaN  NaN         NaN         NaN                    NaN     NaN     NaN
# 256  Sim  Sim         Sim  Eu nao sei                  Facil     Nao  Talvez
# 74   Sim  Sim         Nao  Eu nao sei       Um pouco dificil     Nao  Talvez
# 183  Sim  Nao         Sim         Sim  Nem facil nem dificil  Talvez  Talvez
#
#      Q8   Q9            Q10   Q11        Q12            Q13            Q14  \
# 6     7  NaN            NaN  39.0   Feminino  United States  United States
# 140   7  NaN  Nao aplicavel  32.0     outros  United States  United States
# 256   0  NaN            NaN  42.0   Feminino  United States  United States
# 74   10  NaN            NaN  32.0  Masculino         Canada         Canada
# 183   6  NaN            NaN  33.0  Masculino  United States  United States
#
#      Q15  Q16   Q17
# 6    Sim  Sim  2019
# ...

# %% [markdown]
# ### 2020

# %%
#Leitura do DataFrame
df_2020 = pd.read_csv('2020_f.csv')

#Inserindo a coluna ano
ano_2020 = 2020
df_2020['Ano'] = ano_2020

#Renomeando as colunas para chaves
keys_2020 = ['Q{}'.format(i) for i in range(1,18)]
columns_dic_2020 = pd.Series(df_2020.columns, index=keys_2020)
df_2020.columns = keys_2020

df_2020.sample(5)
# Out:
#      Q1   Q2   Q3          Q4                Q5      Q6      Q7  Q8   Q9  \
# 8   NaN  NaN  NaN         NaN               NaN     NaN     NaN   8  NaN
# 50  Sim  Sim  Sim         Sim           Dificil     Nao  Talvez   9  NaN
# 73  Sim  Sim  Sim         Sim           Dificil     Nao  Talvez   7  NaN
# 62  Nao  Nao  Nao  Eu nao sei  Um pouco dificil  Talvez     Nao   4  NaN
# 76  Sim  Sim  Nao         Sim             Facil  Talvez  Talvez   4  NaN
#
#               Q10   Q11        Q12            Q13            Q14  Q15  Q16  \
# 8   Nao aplicavel  40.0   Feminino         Canada         Canada  NaN  Nao
# 50            NaN  39.0  Masculino  United States  United States  Sim  Sim
# 73            NaN  26.0     Mulher  United States  United States  NaN  Sim
# 62            NaN  33.0   feminino         Canada         Canada  NaN  Nao
# 76            NaN  44.0  masculino  United States  United States  Sim  Sim
#
#      Q17
# 8   2020
# 50  2020
# 73  2020
# 62  2020
# 76  2020

# %% [markdown]
# ## Correções nos Dados Referentes ao Ano de 2016

# %% [markdown]
# Na **coluna Q8** do DataFrame de 2016, os dados estão em formato de ***string***, enquanto nos anos seguintes, a formatação foi alterada para ***inteiros***, com valores variando de 0 a 10.

# %%
df_2016['Q8'].value_counts()
# Out:
# Um pouco aberto                                  573
# Muito aberto                                     224
# Nao muito aberto                                 193
# Neutro                                           120
# Nao aplicavel, eu nao tenho uma doenca mental    101
# Definitivamente nao                               63
# Name: Q8, dtype: int64

# %% [markdown]
# Para realizar a conversão de string para inteiro, foram definidos os seguintes parâmetros, variando de 0 a 10.
#
# |String|Inteiro|
# |:-----|:------:|
# |Um pouco aberto|7|
# |Muito aberto|10|
# |Nao muito aberto|3|
# |Neutro|5|
# |Nao aplicavel, eu nao tenho uma doenca mental|0|
# |Definitivamente nao|0|

# %%
# Mudança dos dados
parametros = {'Um pouco aberto':7,
              'Muito aberto':10,
              'Nao muito aberto':3,
              'Neutro':5,
              'Nao aplicavel, eu nao tenho uma doenca mental':0,
              'Definitivamente nao':0
              }

df_2016['Q8'] = df_2016['Q8'].replace(parametros)

df_2016.sample(5)
# Out:
#               Q1   Q2          Q3          Q4                Q5      Q6  \
# 1256         Sim  Nao  Eu nao sei         Sim     Muito dificil  Talvez
# 767          Sim  Nao  Eu nao sei         Sim             Facil     Sim
# 692   Eu nao sei  Nao  Eu nao sei  Eu nao sei  Um pouco dificil     Sim
# 454          Sim  Sim         Nao  Eu nao sei       Muito Facil     Sim
# 1233         Sim  Sim         Sim  Eu nao sei             Facil     Sim
#
#           Q7  Q8   Q9  Q10   Q11        Q12            Q13            Q14  \
# 1256     Sim   7  NaN  NaN  36.0   feminino  United States  United States
# 767      Sim  10  NaN  NaN  26.0     mulher  United States  United States
# 692   Talvez   7  NaN  NaN  31.0   feminino  United States  United States
# 454      Sim  10  NaN  NaN  29.0  Masculino  United States  United States
# 1233  Talvez   7  NaN  NaN  30.0   Feminino  United States  United States
#
#       Q15  Q16   Q17
# 1256  Sim  Sim  2016
# 767   Sim  Sim  2016
# ...

# %% [markdown]
# ## Leitura do PIB e Correlação com DataFrames Anuais

# %% [markdown]
# Realizada a leitura do DataFrame com os dados referentes ao PIB. Nos DataFrames referentes aos anos de 2016 até 2020, foi incluída em cada um uma nova coluna referente ao PIB de cada país, correlacionando a coluna Q13 (Qual país você reside?) com a 'Country Name'. No DataFrame final, esta nova coluna foi definida como Q18.
#
#  |Chave|Coluna|
#   |:------:|:-----:|
#   |Q18|PIB|

# %% [markdown]
# ### Leitura do DataFrame PIB

# %%
df_pib = pd.read_csv('gdp_data.csv')

# %% [markdown]
# ### 2016

# %%
# Seleção das colunas
df_pib_columns_2016 = df_pib[["Country Name", "2016"]]

# Indexando a coluna Country Names
df_pib_2016 = df_pib_columns_2016.set_index('Country Name')

# Correlacionando os DataFrames
df_2016_completo = pd.merge(df_2016, df_pib_2016, left_on='Q13', right_on='Country Name', how='inner')

# Renomeando a nova coluna
df_2016_completo.rename(columns={'2016': 'Q18'}, inplace=True)

df_2016_completo.sample(5)
# Out:
#               Q1          Q2   Q3          Q4                     Q5   Q6  \
# 268          Sim  Eu nao sei  Sim         Sim            Muito Facil  Sim
# 852          Sim         Nao  Nao  Eu nao sei          Muito dificil  Nao
# 178          Sim         Sim  Nao  Eu nao sei  Nem facil nem dificil  Nao
# 1204         Nao         Nao  Nao  Eu nao sei                  Facil  Nao
# 668   Eu nao sei         Nao  Nao  Eu nao sei             Eu nao sei  Nao
#
#           Q7  Q8   Q9  Q10   Q11        Q12             Q13             Q14  \
# 268   Talvez  10  NaN  NaN  42.0          m   United States   United States
# 852      Nao   3  NaN  NaN  36.0  masculino   United States   United States
# 178      Nao   7  NaN  NaN  39.0          M  United Kingdom  United Kingdom
# 1204     Nao   5  NaN  NaN  37.0          M       Australia       Australia
# 668   Talvez   7  NaN  NaN  24.0  Masculino   United States   United States
#
#       Q15  Q16   Q17           Q18
# ...

# %% [markdown]
# ### 2017

# %%
# Seleção das colunas
df_pib_columns_2017 = df_pib[["Country Name", "2017"]]

# Indexando a coluna Country Names
df_pib_2017 = df_pib_columns_2017.set_index('Country Name')

# Correlacionando os DataFrames
df_2017_completo = pd.merge(df_2017, df_pib_2017, left_on='Q13', right_on='Country Name', how='inner')

# Renomeando a nova coluna
df_2017_completo.rename(columns={'2017': 'Q18'}, inplace=True)

df_2017_completo.sample(5)
# Out:
#                     Q1   Q2          Q3          Q4           Q5   Q6   Q7  \
# 624  Nao elegivel - NA  Sim  Eu nao sei         Sim  Muito Facil  Sim  Sim
# 37                 NaN  NaN         NaN         NaN          NaN  NaN  NaN
# 10                 Sim  Sim         Sim  Eu nao sei  Muito Facil  Sim  Sim
# 296                Sim  Nao         Nao         Sim  Muito Facil  Sim  Sim
# 567                Nao  Nao         Nao         Nao      Dificil  Sim  Sim
#
#      Q8             Q9                Q10   Q11        Q12             Q13  \
# 624  10            NaN                NaN  42.0  Masculino       Australia
# 37    6  Negativamente  Nao tenho certeza  30.0  Masculino  United Kingdom
# 10    9            NaN                NaN  30.0   Feminino  United Kingdom
# 296  10            NaN                NaN  28.0   Feminino   United States
# 567   5            NaN                NaN  40.0  Masculino           India
#
#                 Q14  Q15  Q16   Q17           Q18
# ...

# %% [markdown]
# ### 2018

# %%
# Seleção das colunas
df_pib_columns_2018 = df_pib[["Country Name", "2018"]]

# Indexando a coluna Country Names
df_pib_2018 = df_pib_columns_2018.set_index('Country Name')

# Correlacionando os DataFrames
df_2018_completo = pd.merge(df_2018, df_pib_2018, left_on='Q13', right_on='Country Name', how='inner')

# # Renomeando a nova coluna
df_2018_completo.rename(columns={'2018': 'Q18'}, inplace=True)

df_2018_completo.sample(5)
# Out:
#              Q1          Q2          Q3          Q4                     Q5  \
# 216         Nao         Nao         Nao  Eu nao sei  Nem facil nem dificil
# 320         Nao         Nao         Nao  Eu nao sei            Muito Facil
# 272  Eu nao sei         Nao         Nao  Eu nao sei             Eu nao sei
# 292  Eu nao sei  Eu nao sei  Eu nao sei  Eu nao sei                Dificil
# 270         NaN         NaN         NaN         NaN                    NaN
#
#          Q6      Q7  Q8   Q9          Q10   Q11        Q12            Q13  \
# 216  Talvez  Talvez   9  NaN          NaN  29.0   feminino  United States
# 320  Talvez     Nao   7  NaN          NaN  31.0  Masculino        Germany
# 272  Talvez     Nao   5  NaN          NaN  30.0  Masculino  United States
# 292     Sim  Talvez   5  NaN          NaN  55.0   Feminino  United States
# 270     NaN     NaN   5  NaN  Sem mudanca  57.0  Masculino  United States
#
#                Q14  Q15  Q16   Q17           Q18
# ...

# %% [markdown]
# ### 2019

# %%
# Seleção das colunas
df_pib_columns_2019 = df_pib[["Country Name", "2019"]]

# Indexando a coluna Country Names
df_pib_2019 = df_pib_columns_2019.set_index('Country Name')

# Correlacionando os DataFrames
df_2019_completo = pd.merge(df_2019, df_pib_2019, left_on='Q13', right_on='Country Name', how='inner')

# Renomeando a nova coluna
df_2019_completo.rename(columns={'2019': 'Q18'}, inplace=True)

df_2019_completo.sample(5)
# Out:
#              Q1   Q2          Q3          Q4     Q5      Q6      Q7  Q8   Q9  \
# 31          Sim  Sim         Sim  Eu nao sei  Facil     Sim  Talvez   6  NaN
# 20   Eu nao sei  Nao  Eu nao sei  Eu nao sei  Facil     Nao     Nao  10  NaN
# 219         NaN  NaN         NaN         NaN    NaN     NaN     NaN   2  NaN
# 99   Eu nao sei  Nao  Eu nao sei  Eu nao sei  Facil  Talvez  Talvez   2  NaN
# 187         Sim  Sim         Sim         Sim  Facil  Talvez     Sim  10  NaN
#
#                Q10   Q11        Q12             Q13             Q14  Q15  Q16  \
# 31             NaN  41.0  Masculino   United States   United States  Sim  Sim
# 20             NaN  45.0   feminino   United States   United States  Sim  Sim
# 219  Nao aplicavel  48.0  Masculino  United Kingdom  United Kingdom  NaN  Sim
# 99             NaN  40.0  Masculino   United States   United States  NaN  Nao
# 187            NaN  40.0  masculino   United States   United States  Sim  Sim
#
#       Q17           Q18
# ...

# %% [markdown]
# ### 2020

# %%
# Seleção das colunas
df_pib_columns_2020 = df_pib[["Country Name", "2020"]]

# Indexando a coluna Country Names
df_pib_2020 = df_pib_columns_2020.set_index('Country Name')

# Correlacionando os DataFrames
df_2020_completo = pd.merge(df_2020, df_pib_2020, left_on='Q13', right_on='Country Name', how='inner')

# Renomeando a nova coluna
df_2020_completo.rename(columns={'2020': 'Q18'}, inplace=True)

df_2020_completo.sample(5)
# Out:
#              Q1          Q2          Q3          Q4                     Q5  \
# 131         Sim         Nao         Nao         Sim  Nem facil nem dificil
# 26          Sim         Nao  Eu nao sei  Eu nao sei       Um pouco dificil
# 5           NaN         NaN         NaN         NaN                    NaN
# 59          Sim         Sim         Sim  Eu nao sei             Eu nao sei
# 85   Eu nao sei  Eu nao sei  Eu nao sei         Sim       Um pouco dificil
#
#          Q6      Q7  Q8           Q9            Q10   Q11        Q12  \
# 131     Nao     Nao   0          NaN            NaN  23.0  masculino
# 26   Talvez  Talvez   9          NaN            NaN  42.0  Masculino
# 5       NaN     NaN   7  Sem mudanca  Nao aplicavel  36.0   Feminino
# 59      Sim  Talvez   7          NaN            NaN  48.0          F
# 85      Nao     Nao   2          NaN            NaN  30.0   feminino
#
#                Q13            Q14  Q15  Q16   Q17           Q18
# ...

# %% [markdown]
# ## Concatenação de Todos os DataFrames em um Único DataFrame

# %% [markdown]
# Para conduzir a análise dos dados, foi necessário realizar a concatenação de todos os DataFrames disponíveis em um único DataFrame, proporcionando uma visão abrangente e integrada das informações.

# %%
df_finais = [df_2016_completo,
            df_2017_completo,
            df_2018_completo,
            df_2019_completo,
            df_2020_completo
            ]

df = pd.concat(df_finais)

df.sample(50)
# Out:
#                      Q1          Q2          Q3          Q4  \
# 204                 Sim  Eu nao sei  Eu nao sei         Sim
# 19           Eu nao sei         Nao         Nao  Eu nao sei
# 108                 Sim  Eu nao sei         Sim         Sim
# 625                 NaN         NaN         NaN         NaN
# 783                 Sim         Nao         Sim         Sim
# 1072         Eu nao sei         Nao         Nao  Eu nao sei
# 286                 Sim         Nao  Eu nao sei         Sim
# 139        Nao elegivel         Nao         Nao         Nao
# 1156                Nao         Nao         Nao  Eu nao sei
# 255                 Sim         Sim         Sim         Sim
# 133   Nao elegivel - NA         Nao         Nao         Sim
# 333                 Sim         Nao         Nao  Eu nao sei
# 55                  Sim  Eu nao sei         Sim         Sim
# 196                 Sim         Nao         Nao  Eu nao sei
# 292                 Sim         Nao  Eu nao sei  Eu nao sei
# ...

# %% [markdown]
# ## Organização dos Dados

# %% [markdown]
# Verificando as informações do nosso DataFrame, percebemos que algumas colunas possuem valores faltantes. Realizando o somatório, é possível verificar a quantidade de valores nulos.

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2739 entries, 0 to 139
# Data columns (total 18 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Q1      2315 non-null   object
#  1   Q2      2315 non-null   object
#  2   Q3      2315 non-null   object
#  3   Q4      2315 non-null   object
#  4   Q5      2315 non-null   object
#  5   Q6      2315 non-null   object
#  6   Q7      2315 non-null   object
#  7   Q8      2739 non-null   int64
#  8   Q9      196 non-null    object
#  9   Q10     424 non-null    object
#  10  Q11     2739 non-null   float64
#  11  Q12     2719 non-null   object
#  12  Q13     2739 non-null   object
#  13  Q14     2739 non-null   object
#  14  Q15     1927 non-null   object
#  15  Q16     2739 non-null   object
#  16  Q17     2739 non-null   int64
#  17  Q18     2739 non-null   float64
# dtypes: float64(2), int64(2), object(14)
# memory usage: 406.6+ KB

# %%
df.isna().sum()
# Out:
# Q1      424
# Q2      424
# Q3      424
# Q4      424
# Q5      424
# Q6      424
# Q7      424
# Q8        0
# Q9     2543
# Q10    2315
# Q11       0
# Q12      20
# Q13       0
# Q14       0
# Q15     812
# Q16       0
# Q17       0
# Q18       0
# dtype: int64

# %% [markdown]
# Primeiro verificamos como os dados estão sendo apresentados e realizamos correções.

# %% [markdown]
# ### Organização da coluna Q1

# %%
df['Q1'].value_counts()
# Out:
# Sim                  1276
# Eu nao sei            624
# Nao                   295
# Nao elegivel           66
# Nao elegivel - NA      54
# Name: Q1, dtype: int64

# %% [markdown]
# Nos dados da coluna Q1, foi observado que existem entradas com "Não elegível" e "Não elegível - NA". Esses foram combinados e unificados como "Não elegível"

# %%
q1_parametros = {'Nao elegivel - NA': 'Nao elegivel'}
df['Q1'] = df['Q1'].replace(q1_parametros)
df['Q1'].value_counts()
# Out:
# Sim             1276
# Eu nao sei       624
# Nao              295
# Nao elegivel     120
# Name: Q1, dtype: int64

# %%
df.sample(10)
# Out:
#                 Q1   Q2          Q3          Q4                     Q5  \
# 72    Nao elegivel  Nao  Eu nao sei  Eu nao sei                Dificil
# 233     Eu nao sei  Nao         Nao  Eu nao sei  Nem facil nem dificil
# 115            Sim  Nao         Sim  Eu nao sei                  Facil
# 143            NaN  NaN         NaN         NaN                    NaN
# 42             Sim  Sim         Sim         Sim                  Facil
# 944            Sim  Sim         Sim         Sim                  Facil
# 1211  Nao elegivel  Nao         Nao  Eu nao sei       Um pouco dificil
# 116            NaN  NaN         NaN         NaN                    NaN
# 644     Eu nao sei  Nao  Eu nao sei  Eu nao sei            Muito Facil
# 52             Sim  Sim  Eu nao sei  Eu nao sei                Dificil
#
#           Q6      Q7  Q8   Q9                Q10   Q11        Q12  \
# 72    Talvez  Talvez  10  NaN                NaN  29.0          F
# ...

# %% [markdown]
# ### Organização da coluna Q9

# %%
df['Q9'].value_counts()
# Out:
# Nao tenho certeza    86
# Sim                  32
# Nao                  32
# Negativamente        18
# Sem mudanca          17
# Positivamente        11
# Name: Q9, dtype: int64

# %% [markdown]
# Nos dados da coluna Q9, foram identificadas as respostas "Sim", "Não", "Negativamente" e "Positivamente". Essas foram combinadas e unificadas em "Positivamente" e "Negativamente".

# %%
q9_parametros = {'Sim': 'Negativamente',
                 'Nao': 'Positivamente'
                 }
df['Q9'] = df['Q9'].replace(q9_parametros)
df['Q9'].value_counts()
# Out:
# Nao tenho certeza    86
# Negativamente        50
# Positivamente        43
# Sem mudanca          17
# Name: Q9, dtype: int64

# %%
df.sample(10)
# Out:
#              Q1   Q2          Q3          Q4                     Q5      Q6  \
# 28   Eu nao sei  Nao         Nao         Sim       Um pouco dificil     Nao
# 130         Sim  Sim         Sim  Eu nao sei  Nem facil nem dificil     Sim
# 865         Sim  Nao         Nao  Eu nao sei          Muito dificil  Talvez
# 261         Sim  Sim  Eu nao sei  Eu nao sei             Eu nao sei     Nao
# 22          Sim  Sim         Nao  Eu nao sei             Eu nao sei     Sim
# 604         Nao  Sim         Sim         Nao                  Facil  Talvez
# 319         NaN  NaN         NaN         NaN                    NaN     NaN
# 228  Eu nao sei  Nao         Nao  Eu nao sei             Eu nao sei  Talvez
# 26   Eu nao sei  Sim         Sim  Eu nao sei            Muito Facil     Sim
# 579         Sim  Nao         Nao         Sim       Um pouco dificil  Talvez
#
#          Q7  Q8   Q9                Q10   Q11          Q12             Q13  \
# ...

# %% [markdown]
# ### Organização da coluna Q10

# %% [markdown]
# Nos dados da coluna Q10, foram identificadas as respostas "Sim", "Não", "Negativamente" e "Positivamente". Essas foram combinadas e unificadas em "Positivamente" e "Negativamente".

# %%
df['Q10'].value_counts()
# Out:
# Nao aplicavel        199
# Nao tenho certeza     93
# Nao                   43
# Sim                   30
# Positivamente         23
# Sem mudanca           21
# Negativamente         15
# Name: Q10, dtype: int64

# %%
q10_parametros = {'Sim': 'Negativamente',
                 'Nao': 'Positivamente'
                 }
df['Q10'] = df['Q10'].replace(q10_parametros)
df['Q10'].value_counts()
# Out:
# Nao aplicavel        199
# Nao tenho certeza     93
# Positivamente         66
# Negativamente         45
# Sem mudanca           21
# Name: Q10, dtype: int64

# %%
df.sample(10)
# Out:
#               Q1          Q2          Q3          Q4                     Q5  \
# 229          Sim         Sim         Sim  Eu nao sei       Um pouco dificil
# 1265         Nao         Nao         Nao         Nao                  Facil
# 29           NaN         NaN         NaN         NaN                    NaN
# 86           Nao         Nao         Nao  Eu nao sei             Eu nao sei
# 347          Nao         Sim         Sim  Eu nao sei            Muito Facil
# 846   Eu nao sei         Nao         Nao         Sim            Muito Facil
# 398          Sim         Sim         Sim  Eu nao sei             Eu nao sei
# 524          Sim         Nao  Eu nao sei         Sim  Nem facil nem dificil
# 184          Sim  Eu nao sei  Eu nao sei  Eu nao sei       Um pouco dificil
# 217          Sim         Sim         Sim         Sim                  Facil
#
#           Q6      Q7  Q8   Q9            Q10   Q11        Q12             Q13  \
# ...

# %% [markdown]
# ### Organização da coluna Q12

# %%
df['Q12'].value_counts()
# Out:
# Masculino                    1144
# masculino                     403
# Feminino                      374
# feminino                      210
# M                             137
#                              ...
# cisgênero mulher                1
# MASCULINO                       1
# Me identifico como mulher       1
# Transgênero feminina            1
# Feminino, Ela/Dela              1
# Name: Q12, Length: 72, dtype: int64

# %% [markdown]
# A coluna Q12 apresenta uma variedade de valores. Para facilitar a análise, inicialmente todos os valores foram convertidos para letras minúsculas e os espaços em branco foram removidos. Em seguida, foram definidos os parâmetros "Feminino", "Masculino" e "Outros". Posteriormente, foram excluídas as linhas contendo dados que não puderam ser classificados.

# %% [markdown]
# Para resolver esse problema, os futuros formulários devem ser projetados com opções de seleção de dados, em vez de permitir campos abertos para preenchimento.

# %%
#transformando para letra minuscula e removendo espacos em branco

df['Q12'] = df['Q12'].str.lower()
df['Q12'] = df['Q12'].str.strip()
df['Q12'].value_counts()
# Out:
# masculino                                               1569
# feminino                                                 607
# m                                                        243
# f                                                        124
# cisgênero masculino                                       27
# mulher                                                    22
# cisgênero feminino                                        15
# não binário                                               12
# queer                                                     10
# homem                                                     10
# outros                                                     8
# outro                                                      8
# transgênero                                                8
# não-binário                                                6
# sem gênero                                                 5
# ...

# %%
# Mudança dos parametros

q12_parametros = {'masculino': 'Masculino',
                  'feminino':  'Feminino',
                  'm': 'Masculino',
                  'f':  'Feminino',
                  'cisgênero masculino': 'Masculino',
                  'mulher': 'Feminino',
                  'cisgênero feminino': 'Feminino',
                  'não binário': 'Outros',
                  'queer': 'Outros',
                  'homem': 'Masculino',
                  'outros': 'Outros',
                  'outro': 'Outros',
                  'transgênero': 'Outros',
                  'não-binário': 'Outros',
                  'sem gênero': 'Outros',
                  'nenhum': 'Outros',
                  'gênero fluido': 'Outros',
                  'mascolino': 'Masculino',
                  'cara': 'Masculino',
                  'humano': 'Outros',
                  'contextual': 'Outros',
                  'meu sexo é feminino': 'Feminino',
                  'me identifico como feminina': 'Feminino',
                  'femininu': 'Feminino',
                  'ostensivamente masculino': 'Masculino',
                  'masculino (ei estamos em ti, do que vc está falando)': 'Masculino',
                  'masculino (or feminino, ou ambos)': 'Outros',
                  'vamos manter simples e dizer masculino': 'Masculino',
                  'em dúvida': 'Outros',
                  'maskulino': 'Masculino',
                  'me identifico como homem': 'Masculino',
                  'femenino': 'Feminino',
                  'majoritariamente masculino': 'Masculino',
                  'fem': 'Feminino',
                  'registrada no nascimento como feminino': 'Feminino',
                  'feminino/mulher': 'Feminino',
                  'bi-gênero': 'Outros',
                  'andrôgeno': 'Outros',
                  '90% masculino, 10% feminino': 'Outros',
                  'fluido': 'Outros',
                  'eu sou um homem!': 'Masculino',
                  'm|': 'Masculino',
                  'masculino.': 'Masculino',
                  'fluidez de gênero (nascida feminino)': 'Outros',
                  'sexo é masculino': 'Masculino',
                  'não é da sua conta': 'Outros',
                  'cisgênero mulher': 'Feminino',
                  'me identifico como mulher': 'Feminino',
                  'transgênero feminina': 'Outros',
                  'feminino, ela/dela': 'Feminino'
                  }

df['Q12'] = df['Q12'].replace(q12_parametros)
df['Q12'].value_counts()
# Out:
# Masculino    1863
# Feminino      778
# Outros         76
# unicórnio       1
# \----           1
# Name: Q12, dtype: int64

# %%
# Excluindo as linhas
df.loc[df['Q12'] == 'unicórnio', 'Q12'] = np.nan
df.loc[df['Q12'] == '\----', 'Q12'] = np.nan
df['Q12'].value_counts()
# Out:
# Masculino    1863
# Feminino      778
# Outros         76
# Name: Q12, dtype: int64

# %%
df.sample(10)
# Out:
#                 Q1   Q2          Q3          Q4                Q5      Q6  \
# 0     Nao elegivel  Nao         Nao  Eu nao sei       Muito Facil     Sim
# 1119           Nao  Sim         Nao  Eu nao sei     Muito dificil     Sim
# 673            NaN  NaN         NaN         NaN               NaN     NaN
# 141     Eu nao sei  Sim  Eu nao sei  Eu nao sei             Facil     Sim
# 182            Sim  Sim         Nao         Sim  Um pouco dificil     Sim
# 164   Nao elegivel  Nao         Nao  Eu nao sei             Facil     Sim
# 23             Sim  Nao  Eu nao sei  Eu nao sei       Muito Facil  Talvez
# 116            Sim  Sim         Sim         Nao  Um pouco dificil  Talvez
# 50    Nao elegivel  Nao         Nao  Eu nao sei        Eu nao sei  Talvez
# 1041           Sim  Nao         Nao  Eu nao sei     Muito dificil  Talvez
#
#           Q7  Q8                 Q9            Q10   Q11        Q12  \
# 0     Talvez   7                NaN            NaN  39.0  Masculino
# ...

# %% [markdown]
# ##Limpeza dos Dados

# %% [markdown]
# ### Limpeza de todos os valores nulos do DataFrame

# %% [markdown]
# Os valores nulos foram transformados em N/A. Devido à classificação de todas as colunas nulas como objeto, não foi possível realizar o preenchimento utilizando a média ou a mediana.

# %%
df.fillna('N/A', inplace=True)

# %%
df.sample(15)
# Out:
#              Q1          Q2          Q3          Q4                     Q5  \
# 533         Sim         Nao         Nao         Sim            Muito Facil
# 436         Sim         Nao         Nao  Eu nao sei  Nem facil nem dificil
# 71          Sim         Nao         Nao  Eu nao sei                  Facil
# 439         Sim         Nao  Eu nao sei  Eu nao sei                  Facil
# 191         Sim         Sim         Sim         Sim  Nem facil nem dificil
# 90          Sim  Eu nao sei  Eu nao sei  Eu nao sei             Eu nao sei
# 246         Sim         Sim  Eu nao sei         Sim       Um pouco dificil
# 463         N/A         N/A         N/A         N/A                    N/A
# 26   Eu nao sei         Sim         Sim  Eu nao sei            Muito Facil
# 582         Sim         Sim         Sim  Eu nao sei  Nem facil nem dificil
# 248         Sim         Nao         Nao  Eu nao sei                  Facil
# ...

# %%
df.isna().sum()
# Out:
# Q1     0
# Q2     0
# Q3     0
# Q4     0
# Q5     0
# Q6     0
# Q7     0
# Q8     0
# Q9     0
# Q10    0
# Q11    0
# Q12    0
# Q13    0
# Q14    0
# Q15    0
# Q16    0
# Q17    0
# Q18    0
# dtype: int64

# %% [markdown]
# ### Valores Duplicados

# %% [markdown]
# Remover valores duplicados é essencial para manter a precisão dos dados. Ao eliminar entradas repetidas, evitamos distorções nos resultados, garantindo análises confiáveis e consistentes.

# %%
# Mostra as quantidade de linhas que estão duplicadas
dups = df.duplicated()
print('Número de linhas duplicadas = %d' % (dups.sum()))
# Out:
# Número de linhas duplicadas = 6

# %%
df[df.duplicated()] # Mostra as linhas que estão duplicadas
# Out:
#       Q1   Q2          Q3          Q4             Q5      Q6      Q7  Q8  \
# 494  N/A  N/A         N/A         N/A            N/A     N/A     N/A   7
# 601  N/A  N/A         N/A         N/A            N/A     N/A     N/A   7
# 865  Sim  Nao         Nao  Eu nao sei  Muito dificil  Talvez  Talvez   7
# 898  Sim  Nao  Eu nao sei  Eu nao sei    Muito Facil  Talvez  Talvez  10
# 996  Sim  Sim         Sim  Eu nao sei          Facil     Sim  Talvez   7
# 503  Sim  Sim         Sim         Sim     Eu nao sei  Talvez  Talvez   8
#
#                     Q9                Q10   Q11        Q12            Q13  \
# 494  Nao tenho certeza  Nao tenho certeza  30.0  Masculino  United States
# 601                N/A      Nao aplicavel  42.0  Masculino  United States
# 865                N/A                N/A  33.0  Masculino  United States
# 898                N/A                N/A  39.0  Masculino  United States
# 996                N/A                N/A  30.0   Feminino  United States
# ...

# %%
# Remove as linhas que estão duplicadas
print('Número de linhas antes de descartar duplicatas = %d' % (df.shape[0]))
df.drop_duplicates(inplace=True)
print('Número de linhas após o descarte de duplicatas = %d' % (df.shape[0]))
# Out:
# Número de linhas antes de descartar duplicatas = 2739
# Número de linhas após o descarte de duplicatas = 2733

# %% [markdown]
# ### Outliers

# %% [markdown]
# Optou-se por analisar os possíveis outliers de cada coluna numérica separadamente, utilizando um gráfico boxplot.

# %% [markdown]
# A coluna Q17 é numérica; no entanto, não será analisada, pois contém apenas os anos em que a pesquisa foi realizada e foi adicionada apenas para esse propósito.

# %% [markdown]
# #### Q8

# %%
df['Q8'].plot(kind='box')
# Out:
# <Axes: >

# %% [markdown]
# Foram observados outliers na coluna Q8, possivelmente decorrentes das correções nos dados feitas em 2016. Inicialmente, o formulário era aberto, mas posteriormente foi ajustado para uma escala de 0 a 10.

# %% [markdown]
# Devido a esses motivos, optou-se por remover os outliers utilizando como limite 1,5 desvios-padrão acima da média.

# %%
# Média, desvio padrão e limites

mean = df['Q8'].mean()
std_dev = df['Q8'].std()

limite_superior = mean + 1.5 * std_dev
limite_inferior = mean - 1.5 * std_dev

print(limite_superior)
print(limite_inferior)
print(mean)
# Out:
# 10.525823318206674
# 1.8232436411786175
# 6.174533479692646

# %%
# Verificando os outliers
outliers = df[(df['Q8'] > limite_superior) | (df['Q8'] < limite_inferior)]
print(outliers)
# Out:
#                Q1   Q2          Q3          Q4                     Q5      Q6  \
# 24            N/A  N/A         N/A         N/A                    N/A     N/A
# 35     Eu nao sei  Nao  Eu nao sei  Eu nao sei             Eu nao sei  Talvez
# 39            N/A  N/A         N/A         N/A                    N/A     N/A
# 41   Nao elegivel  Nao         Nao         Nao       Um pouco dificil     Sim
# 51            N/A  N/A         N/A         N/A                    N/A     N/A
# ..            ...  ...         ...         ...                    ...     ...
# 72   Nao elegivel  Nao  Eu nao sei  Eu nao sei                Dificil     Nao
# 75            Nao  Nao         Nao         Nao                Dificil     Nao
# 89            Nao  Nao         Nao  Eu nao sei                Dificil     Nao
# 98            N/A  N/A         N/A         N/A                    N/A     N/A
# 131           Sim  Nao         Nao         Sim  Nem facil nem dificil     Nao
#
# ...

# %%
# Retirando os outliers

df.loc[df['Q8'] > limite_superior, 'Q8'] = mean
df.loc[df['Q8'] < limite_inferior, 'Q8'] = mean

# %%
df['Q8'].plot(kind='box')
# Out:
# <Axes: >

# %% [markdown]
# O novo gráfico boxplot mostra que não há mais valores com outliers.

# %% [markdown]
# #### Q11

# %%
df['Q11'].plot(kind='box')
# Out:
# <Axes: >

# %% [markdown]
# Na coluna Q11, há muitos valores que são outliers, especialmente por se tratar da idade, podendo ser influenciados por diversos fatores que contribuem para a presença desses valores discrepantes.

# %% [markdown]
# Foi escolhida a **"regra dos 1,5*IQR"** para retirar os outliers devido à sua simplicidade e robustez. Essa técnica equilibra bem entre ser cuidadosa e sensível na detecção desses valores diferentes.

# %%
Q1 = df['Q11'].quantile(0.25) #primeiro quartil
Q3 = df['Q11'].quantile(0.75) #terceiro quartil

IQR = Q3-Q1 #  intervalo interquartil

inferior = Q3+1.5 *IQR #limite inferior
superior = Q1-1.5 *IQR #limite superior

print(f'IQR = {IQR}')
print(f'Limite inferior = {inferior}')
print(f'Limite superior = {superior}')
# Out:
# IQR = 11.0
# Limite inferior = 56.5
# Limite superior = 12.5

# %%
# Filtra a linha mantendo apenas as linhas onde a condição especificada
df = df[(df['Q11'] >= superior) & (df['Q11'] <= inferior)]

# %%
df['Q11'].hist()
# Out:
# <Axes: >

# %% [markdown]
# Ao plotar o histograma, constatamos que os valores agora seguem uma distribuição mais próxima da normal.

# %%
df['Q11'].plot(kind='box')
# Out:
# <Axes: >

# %% [markdown]
# Ao realizar novamente o boxplot, ainda são identificados alguns outliers, porém esses dados são considerados legítimos e não serão removidos.

# %%
df['Q17'].plot(kind='box')
# Out:
# <Axes: >

# %% [markdown]
# #### Q18

# %%
df['Q18'].plot(kind='box')
# Out:
# <Axes: >

# %% [markdown]
# A coluna Q18 refere-se aos valores de PIB, no entanto, ao realizar o boxplot, não foram identificados outliers.

# %% [markdown]
# # Perguntas

# %% [markdown]
# ## 1. Existe uma diferença significativa de saúde mental entre os gêneros de colaboradores ao longo do tempo em que a pesquisa foi realizada?

# %%
df_pergunta1 = df[['Q12','Q15','Q17']] #Dataframe apenas com as colunas necessárias

# %%
# Retirando os itens nulos da análise
df_pergunta1 = df_pergunta1[df_pergunta1['Q12'] != 'N/A']
df_pergunta1 = df_pergunta1[df_pergunta1['Q15'] != 'N/A']

df_pergunta1.sample(10)
# Out:
#            Q12  Q15   Q17
# 569   Feminino  Nao  2016
# 454  Masculino  Sim  2017
# 429  Masculino  Sim  2016
# 715  Masculino  Nao  2016
# 36   Masculino  Sim  2017
# 243  Masculino  Sim  2016
# 268  Masculino  Sim  2016
# 26   Masculino  Nao  2016
# 667  Masculino  Nao  2016
# 482  Masculino  Sim  2016

# %% [markdown]
# Será criada uma tabela dinâmica que mostra a proporção de respostas 'Sim' para a coluna Q15 (Você já foi diagnosticado com uma doença mental?) em relação ao total de respostas para cada combinação única de valores nas colunas Q17 (Ano) e Q12 (Gênero).

# %%
proporcoes_sim1 = df_pergunta1.pivot_table(index='Q17', columns='Q12', values='Q15', aggfunc=lambda x: (x == 'Sim').mean())

# %%
proporcoes_sim1.plot(kind='bar', figsize=(10, 6), color=['#ff6f69', '#88d8b0', '#ffcc5c'])
plt.title('Proporção de Diagnósticos de Doença Mental por Gênero ao Longo do Tempo')
plt.xlabel('Ano')
plt.ylabel('Proporção de Respostas')
plt.xticks(rotation=0)
plt.legend(title='Gênero')
plt.grid(axis='y')

# %% [markdown]
# Observamos que houve um aumento significativo nos casos de diagnóstico de doença mental entre indivíduos do gênero masculino ao longo dos anos. O gênero feminino também apresentou um aumento, mantendo-se consistentemente maior que o número de casos de diagnóstico em homens, com apenas uma pequena diferença em 2018. Quanto aos outros gêneros, os diagnósticos de doença mental parecem estar aumentando ao longo dos anos, embora não tenhamos informações para o ano de 2020.

# %% [markdown]
# ## 2. Existe uma diferença significativa de quem busca tratamento entre os gêneros de colaboradores ao longo do tempo em que a pesquisa foi realizada?

# %%
df_pergunta2 = df[['Q12','Q16','Q17']]  #Dataframe apenas com as colunas necessárias

# %%
# Retirando os itens nulos da análise
df_pergunta2 = df_pergunta2[df_pergunta2['Q12'] != 'N/A']
df_pergunta2 = df_pergunta2[df_pergunta2['Q16'] != 'N/A']

df_pergunta2.sample(10)
# Out:
#             Q12  Q16   Q17
# 49    Masculino  Sim  2019
# 270    Feminino  Sim  2016
# 227   Masculino  Nao  2017
# 492    Feminino  Sim  2016
# 144    Feminino  Sim  2018
# 1185   Feminino  Sim  2016
# 520   Masculino  Sim  2016
# 1041  Masculino  Sim  2016
# 12     Feminino  Nao  2017
# 173   Masculino  Sim  2018

# %% [markdown]
# Será criada uma tabela dinâmica que mostra a proporção de respostas 'Sim' para a coluna Q16 (Voce ja procurou tratamento profissional para uma doenca mental?) em relação ao total de respostas para cada combinação única de valores nas colunas Q17 (Ano) e Q12 (Gênero).

# %%
proporcoes_sim2 = df_pergunta2.pivot_table(index='Q17', columns='Q12', values='Q16', aggfunc=lambda x: (x == 'Sim').mean())

# %%
proporcoes_sim2.plot(kind='bar', figsize=(10, 6), color=['#ff6f69', '#88d8b0', '#ffcc5c'])
plt.title('Proporção de Busca por Tratamento Profissional para Doença Mental por Gênero ao Longo do Tempo')
plt.xlabel('Ano')
plt.ylabel('Proporção de Respostas')
plt.xticks(rotation=0)
plt.legend(title='Gênero')
plt.grid(axis='y')

# %% [markdown]
# O gênero feminino e os outros gêneros são os que mais buscam tratamento profissional para doença mental. Enquanto isso, para o gênero masculino, observamos que está sempre abaixo do gênero feminino e dos outros. No entanto, em 2022, essa tendência se inverte, com o gênero masculino buscando mais tratamento do que o gênero feminino, e não possuímos dados sobre os outros gêneros

# %% [markdown]
# ## 3. Existe uma diferença significativa de saúde mental entre as idades dos colaboradores ao longo do tempo em que a pesquisa foi realizada?

# %% [markdown]
# Para a análise de idade, primeiro foram criados rótulos para facilitar a análise com gráficos.

# %%
intervalos = [14, 21, 31, 41, 51, 56]
rotulos = ['14-20', '21-30', '31-40', '41-50', '51-60+']

# %%
df['Q11'] = pd.cut(df['Q11'], bins=intervalos, labels=rotulos) # Criação dos rótulos

# %%
df['Q11'].value_counts() # Verificando a quantidade em cada rótulo
# Out:
# 31-40     1092
# 21-30     1039
# 41-50      420
# 51-60+      75
# 14-20       50
# Name: Q11, dtype: int64

# %%
df_pergunta3 = df[['Q11','Q15','Q17']] # Dataframe apenas com as colunas necessárias
df_pergunta3 = df_pergunta3[df_pergunta3['Q15'] != 'N/A'] # Retirando os itens nulos da análise

# %%
df_pergunta3.sample(10)
# Out:
#          Q11  Q15   Q17
# 410    21-30  Sim  2017
# 1060   21-30  Nao  2016
# 151    21-30  Nao  2016
# 1186   21-30  Sim  2016
# 666   51-60+  Nao  2016
# 1043   21-30  Nao  2016
# 196    21-30  Sim  2018
# 559    21-30  Sim  2016
# 645    41-50  Nao  2016
# 556   51-60+  Nao  2016

# %% [markdown]
# Será criada uma tabela dinâmica que mostra a proporção de respostas 'Sim' para a coluna Q15 (Você já foi diagnosticado com uma doença mental?) em relação ao total de respostas para cada combinação única de valores nas colunas Q17 (Ano) e Q11 (Idade).

# %%
proporcoes_sim3 = df_pergunta3.pivot_table(index='Q17', columns='Q11', values='Q15', aggfunc=lambda x: (x == 'Sim').mean())

# %%
proporcoes_sim3.plot(kind='bar', figsize=(10, 6), color=['#ff6f69', '#88d8b0', '#ffcc5c', '#6eafe8', '#a89dbd'])
plt.title('Proporção de Diagnósticos de Doença Mental por Faixas Etárias ao Longo do Tempo')
plt.xlabel('Ano')
plt.ylabel('Proporção de Respostas')
plt.xticks(rotation=0)
plt.legend(title='Gênero')
plt.grid(axis='y')

# %% [markdown]
# Ao longo dos anos, não foram observadas diferenças discrepantes nos diagnósticos de saúde mental por faixas etárias. No entanto, é possível notar uma redução no ano de 2020 na faixa etária entre 21 e 30 anos.

# %% [markdown]
# ## 4. Existe uma diferença significativa de quem busca tratamento entre as idades dos colaboradores ao longo do tempo em que a pesquisa foi realizada?

# %%
df_pergunta4 = df[['Q11','Q16','Q17']] # Dataframe apenas com as colunas necessárias
df_pergunta4 = df_pergunta4[df_pergunta4['Q16'] != 'N/A'] # Retirando os itens nulos da análise

# %%
df_pergunta4.sample(10)
# Out:
#        Q11  Q16   Q17
# 487  31-40  Nao  2016
# 238  21-30  Sim  2017
# 855  21-30  Sim  2016
# 371  31-40  Sim  2017
# 210  31-40  Nao  2019
# 183  31-40  Sim  2016
# 115  31-40  Nao  2016
# 172  41-50  Nao  2017
# 118  31-40  Sim  2020
# 204  31-40  Nao  2017

# %% [markdown]
# Será criada uma tabela dinâmica que mostra a proporção de respostas 'Sim' para a coluna Q16 (Voce ja procurou tratamento profissional para uma doenca mental?) em relação ao total de respostas para cada combinação única de valores nas colunas Q17 (Ano) e Q11 (Idade).

# %%
proporcoes_sim4 = df_pergunta4.pivot_table(index='Q17', columns='Q11', values='Q16', aggfunc=lambda x: (x == 'Sim').mean())

# %%
proporcoes_sim4.plot(kind='bar', figsize=(10, 6), color=['#ff6f69', '#88d8b0', '#ffcc5c', '#6eafe8', '#a89dbd'])
plt.title('Proporção de Busca por Tratamento Profissional para Doença Mental por Faixa Etária ao Longo do Tempo')
plt.xlabel('Ano')
plt.ylabel('Proporção de Respostas')
plt.xticks(rotation=0)
plt.legend(title='Gênero')
plt.grid(axis='y')

# %% [markdown]
# Todas as faixas etárias estão demonstrando, ao longo dos anos, um padrão semelhante em relação à busca por tratamento profissional, sem muita variação. No entanto, a faixa etária entre 14 e 20 anos apresenta flutuações significativas ao longo do tempo, com um pico de procura por tratamento em 2019 e uma redução drástica em 2020. Essas variações abruptas podem ser atribuídas ao fato de que o número de pessoas nesta faixa etária é consideravelmente menor em comparação com as faixas etárias de 31 a 40 e de 21 a 30 anos.

# %% [markdown]
# ## 5. Os funcionários de empresas que possuem benefícios de saúde para tratamento de saúde mental buscam mais tratamento?

# %%
df_pergunta4 = df[['Q1','Q16']] # Dataframe apenas com as colunas necessárias
df_pergunta4 = df_pergunta4[~df_pergunta4['Q1'].isin(['N/A', 'Eu nao sei', 'Nao elegivel'])] # Excluindo os itens nulos e as respostas inconclusivas da análise.

# %%
df_pergunta4['Q1'].value_counts() # Realizando a contagem para verificar se todas as respostas inconclusivas foram removidas da análise.
# Out:
# Sim    1245
# Nao     292
# Name: Q1, dtype: int64

# %% [markdown]
# Os dados foram agrupados de acordo com a oferta de benefícios relacionados à saúde mental pela empresa e, em seguida, foi feita uma contagem para verificar se cada indivíduo procurou tratamento profissional para uma doença mental ou não. Para facilitar a visualização, os dados foram normalizados, dividindo as contagens pelo total de elementos em cada grupo.

# %%
tratamento_por_beneficios = df_pergunta4.groupby('Q1')['Q16'].value_counts(normalize=True).unstack()

# %%
tratamento_por_beneficios.plot(kind='barh', stacked=True, color=['#ff6f69', '#88d8b0'])

plt.xlabel('Proporção de Funcionários')
plt.ylabel('Oferece Benefícios de Saúde')
plt.title('Funcionários que Procuraram Tratamento por Benefícios de Saúde')
plt.legend(title='Procurou Tratamento', loc='upper right')

# %% [markdown]
# Com esse gráfico, fica claro que os funcionários com benefícios de saúde mental buscam mais tratamento do que aqueles sem esses benefícios. Isso sugere que os benefícios podem influenciar positivamente a procura por cuidados profissionais.

# %% [markdown]
# ## 6. Existe uma diferença significativa de saúde mental entre países mais ricos (com um PIB elevado) no ano de 2016?

# %%
df_pergunta5 = df.loc[(df['Q15'] == 'Sim') & (df['Q17'] == 2016)] # Filtrando apenas diagnósticos positivos do ano de 2016.

# %%
df_pergunta5 = df_pergunta5[['Q15','Q13', 'Q17', 'Q18']] # Dataframe apenas com as colunas necessárias
df_pergunta5.sample(10)
# Out:
#       Q15             Q13   Q17           Q18
# 807   Sim   United States  2016  1.869511e+13
# 515   Sim   United States  2016  1.869511e+13
# 1264  Sim          Brazil  2016  1.795700e+12
# 365   Sim   United States  2016  1.869511e+13
# 789   Sim   United States  2016  1.869511e+13
# 804   Sim   United States  2016  1.869511e+13
# 190   Sim   United States  2016  1.869511e+13
# 55    Sim  United Kingdom  2016  2.699660e+12
# 912   Sim   United States  2016  1.869511e+13
# 748   Sim   United States  2016  1.869511e+13

# %%
df_pergunta5['Q13'].value_counts() # Realizando a contagem por país
# Out:
# United States     460
# United Kingdom     76
# Canada             29
# Netherlands        25
# Australia          23
# Germany            21
# France              5
# Brazil              4
# India               3
# Name: Q13, dtype: int64

# %% [markdown]
# Para a análise, será necessário agrupar o número de respostas positivas por país, juntamente com os valores correspondentes do PIB.

# %%
resultados = df_pergunta5[df_pergunta5['Q15'] == 'Sim'].groupby('Q13').size().reset_index(name='Q15')
resultados = resultados.merge(df_pergunta5[['Q13', 'Q18']].drop_duplicates(), on='Q13')
resultados
# Out:
#               Q13  Q15           Q18
# 0       Australia   23  1.206535e+12
# 1          Brazil    4  1.795700e+12
# 2          Canada   29  1.527995e+12
# 3          France    5  2.472964e+12
# 4         Germany   21  3.469853e+12
# 5           India    3  2.294798e+12
# 6     Netherlands   25  7.840604e+11
# 7  United Kingdom   76  2.699660e+12
# 8   United States  460  1.869511e+13

# %%
resultados = resultados.sort_values(by='Q18', ascending=False) # Organizar a tabela em ordem decrescente com base no PIB
resultados
# Out:
#               Q13  Q15           Q18
# 8   United States  460  1.869511e+13
# 4         Germany   21  3.469853e+12
# 7  United Kingdom   76  2.699660e+12
# 3          France    5  2.472964e+12
# 5           India    3  2.294798e+12
# 1          Brazil    4  1.795700e+12
# 2          Canada   29  1.527995e+12
# 0       Australia   23  1.206535e+12
# 6     Netherlands   25  7.840604e+11

# %%
resultados = resultados.head(3) # Selecionar as três primeiras linhas que correspondem aos três países mais ricos.
resultados
# Out:
#               Q13  Q15           Q18
# 8   United States  460  1.869511e+13
# 4         Germany   21  3.469853e+12
# 7  United Kingdom   76  2.699660e+12

# %%
plt.figure(figsize=(10, 6))
plt.barh(resultados['Q13'], resultados['Q15'], color='#6eafe8')

plt.title('Relação entre PIB e Saúde Mental por País')
plt.xlabel('Número de Pessoas com Problemas de Saúde Mental')
plt.ylabel('País')
# Out:
# Text(0, 0.5, 'País')

# %%
df['Q13'].value_counts() # Contagem de respostas por país
# Out:
# United States     1870
# United Kingdom     298
# Canada             132
# Germany             96
# Netherlands         75
# India               73
# Australia           54
# France              40
# Brazil              38
# Name: Q13, dtype: int64

# %% [markdown]
# A análise revela que os Estados Unidos possuem o maior PIB e o maior número de diagnósticos positivos. Em comparação com os outros dois países ricos, há uma grande discrepância. No entanto, é importante notar que os dados podem estar enviesados a favor dos Estados Unidos devido ao país ter 1870 respostas, enquanto o Reino Unido tem 298 respostas e a Alemanha tem 96.
